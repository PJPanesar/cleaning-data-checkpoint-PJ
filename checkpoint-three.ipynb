# %% [markdown]
# # Checkpoint Three: Cleaning Data
#
# Now you are ready to clean your data. Before starting coding, provide the link to your dataset below.
#
# My dataset:
#
# Import the necessary libraries and create your dataframe(s).

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.close("all")
import numpy as np
import os
os.chdir(r"C:\Users\prabh\MyFirstProject\Final Project\eda-checkpoint-PJPanesar")


print(os.getcwd())
print(os.listdir())


Mo_Cataract = pd.read_csv("Cataract Diagnosed Medicare 65 and older (Ethnicity).csv")
Mo_AMD = pd.read_csv("AMD Medicare (Ethnicity).csv")
Mo_Glaucoma = pd.read_csv("Glaucoma Medicare (Ethnicity).csv")
Mo_Cornea = pd.read_csv("Other Cornea Disease Medicare (Ethnicity).csv")
Mo_Retina = pd.read_csv("Other Retina Disease Medicare (Ethnicity).csv")


National_Cataract = pd.read_csv("National Catract Diagnosed by State (Ethnicity).csv")
National_AMD = pd.read_csv("AMD NAtional by State Medicare (Ethnicity).csv")
National_Glaucoma = pd.read_csv("Glaucoma National Medicare by State (Ethnicity).csv")
National_Cornea = pd.read_csv("National Corea Disease by State Medicare (Ethnicity).csv")
National_Retina = pd.read_csv("National Retina Disease by State Medicare (Ethnicity).csv")
# Out:
# C:\Users\prabh\MyFirstProject\Final Project\eda-checkpoint-PJPanesar
# ['.gitignore', 'AMD Medicare (Ethnicity).csv', 'AMD NAtional by State Medicare (Ethnicity).csv', 'AMD National Medicare (Ethnicity).csv', 'Cataract Diagnosed Medicare 65 and older (Ethnicity).csv', 'Cataract Treatment Medicare 65 and older (Ethnicity).csv', 'checkpoint-two.ipynb', 'Glaucoma Medicare (Ethnicity).csv', 'Glaucoma National Medicare by State (Ethnicity).csv', 'National Cataract Treatment by State (Ethnicity).csv', 'National Catract Diagnosed by State (Ethnicity).csv', 'National Corea Disease by State Medicare (Ethnicity).csv', 'National Retina Disease by State Medicare (Ethnicity).csv', 'NHISVisionData.xlsx', 'Other Cornea Disease Medicare (Ethnicity).csv', 'Other Retina Disease Medicare (Ethnicity).csv']

# %% [markdown]
# ## Missing Data
#
# Test your dataset for missing data and handle it as needed. Make notes in the form of code comments as to your thought process.

# %%
Mo_Cataract.info()
#I want to see what columns are blank. From this I see that Countyname, Topic, Category, Data_Value_Footnote_Symbol, Data_Value_Footnote have 0 non null values. This will be the same for all of the other Data Sets.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 26 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   YearStart                   7 non-null      float64
#  1   YearEnd                     7 non-null      float64
#  2   LocationAbbr                7 non-null      object
#  3   LocationDesc                7 non-null      object
#  4   CountyName                  0 non-null      float64
#  5   DataSource                  7 non-null      object
#  6   Topic                       0 non-null      float64
#  7   Category                    0 non-null      float64
#  8   Question                    7 non-null      object
#  9   Response                    7 non-null      object
#  10  Age                         7 non-null      object
#  11  Sex                         7 non-null      object
#  12  Race_Ethnicity              7 non-null      object
# ...

# %%
Mo_AMD.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 23 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   YearStart                   7 non-null      int64
#  1   YearEnd                     7 non-null      int64
#  2   LocationAbbr                7 non-null      object
#  3   LocationDesc                7 non-null      object
#  4   CountyName                  0 non-null      float64
#  5   DataSource                  7 non-null      object
#  6   Topic                       0 non-null      float64
#  7   Category                    0 non-null      float64
#  8   Question                    7 non-null      object
#  9   Response                    7 non-null      object
#  10  Age                         7 non-null      object
#  11  Sex                         7 non-null      object
#  12  Race_Ethnicity              7 non-null      object
# ...

# %%
Mo_Glaucoma.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 26 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   YearStart                   7 non-null      int64
#  1   YearEnd                     7 non-null      int64
#  2   LocationAbbr                7 non-null      object
#  3   LocationDesc                7 non-null      object
#  4   CountyName                  0 non-null      float64
#  5   DataSource                  7 non-null      object
#  6   Topic                       0 non-null      float64
#  7   Category                    0 non-null      float64
#  8   Question                    7 non-null      object
#  9   Response                    7 non-null      object
#  10  Age                         7 non-null      object
#  11  Sex                         7 non-null      object
#  12  Race_Ethnicity              7 non-null      object
# ...

# %%
Mo_Cornea.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 23 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   YearStart                   7 non-null      int64
#  1   YearEnd                     7 non-null      int64
#  2   LocationAbbr                7 non-null      object
#  3   LocationDesc                7 non-null      object
#  4   CountyName                  0 non-null      float64
#  5   DataSource                  7 non-null      object
#  6   Topic                       0 non-null      float64
#  7   Category                    0 non-null      float64
#  8   Question                    7 non-null      object
#  9   Response                    7 non-null      object
#  10  Age                         7 non-null      object
#  11  Sex                         7 non-null      object
#  12  Race_Ethnicity              7 non-null      object
# ...

# %%
Mo_Retina.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 23 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   YearStart                   7 non-null      int64
#  1   YearEnd                     7 non-null      int64
#  2   LocationAbbr                7 non-null      object
#  3   LocationDesc                7 non-null      object
#  4   CountyName                  0 non-null      float64
#  5   DataSource                  7 non-null      object
#  6   Topic                       0 non-null      float64
#  7   Category                    0 non-null      float64
#  8   Question                    7 non-null      object
#  9   Response                    7 non-null      object
#  10  Age                         7 non-null      object
#  11  Sex                         7 non-null      object
#  12  Race_Ethnicity              7 non-null      object
# ...

# %% [markdown]
# ## Irregular Data
#
# Detect outliers in your dataset and handle them as needed. Use code comments to make notes about your thought process.

# %%
National_Cataract.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 378 entries, 0 to 377
# Data columns (total 29 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   YearStart                         378 non-null    int64
#  1   YearEnd                           378 non-null    int64
#  2   LocationAbbr                      378 non-null    object
#  3   LocationDesc                      378 non-null    object
#  4   CountyName                        0 non-null      float64
#  5   DataSource                        378 non-null    object
#  6   Topic                             0 non-null      float64
#  7   Category                          0 non-null      float64
#  8   Question                          378 non-null    object
#  9   Response                          378 non-null    object
#  10  Age                               378 non-null    object
# ...

# %% [markdown]
# ## Unnecessary Data
#
# Look for the different types of unnecessary data in your dataset and address it as needed. Make sure to use code comments to illustrate your thought process.

# %%
#Mo_Cataract.head(20)
#There are a lot of unessecary columns such as Data_Value Footnote, Data_Value_Footnote Symbol, Topic, Category, Countyname, etc.... I will have to remove them from the dataset
# Mo_Cataract = Mo_Cataract.drop(
# columns=["Data_Value_Footnote", "Data_Value_Footnote_Symbol"]
# )
#Mo_Cataract = Mo_Cataract.drop(
#columns=["Topic", "FootnoteText", "Url", "FootnoteType", "Risk_Factor_Repsonse", "Category", "Question", "Response", ]
#)
#Mo_Cataract = Mo_Cataract.drop(
#columns=["Data_Value_Type", "Risk_Factor", "CountyName" ]
#)
#Mo_AMD = Mo_AMD.drop(
#columns=["Data_Value_Footnote", "Data_Value_Footnote_Symbol", "Topic", "Risk_Factor_Repsonse", "Category", "Question", "Response", "Data_Value_Type", "Risk_Factor", "CountyName"]
#)
#Mo_Glaucoma = Mo_Glaucoma.drop(
#columns=["Data_Value_Footnote", "Data_Value_Footnote_Symbol", "Topic", "Risk_Factor_Repsonse", "Category", "Question", "Response", "Data_Value_Type", "Risk_Factor", "CountyName", "FootnoteText", "Url", "FootnoteType"]
#)
#Mo_Cornea = Mo_Cornea.drop(
#columns=["Data_Value_Footnote", "Data_Value_Footnote_Symbol", "Topic", "Risk_Factor_Repsonse", "Category", "Question", "Response", "Data_Value_Type", "Risk_Factor", "CountyName",]
#)
#Mo_Retina = Mo_Retina.drop(
#columns=["Data_Value_Footnote", "Data_Value_Footnote_Symbol", "Topic", "Risk_Factor_Repsonse", "Category", "Question", "Response", "Data_Value_Type", "Risk_Factor", "CountyName"]
#)

# %%
#National_Cataract_clean = National_Cataract[
#National_Cataract["LocationDesc"].isin(["Missouri", "National"])
#]
#National_Cataract_clean = National_Cataract_clean.drop(
#columns=[
#"Risk_Factor_Response", "Data_Value_Footnote", "Data_Value_Footnote_Symbol", "Topic", "Category", "Question", "Response", "Data_Value_Type", "Risk_Factor", "CountyName", "FootnoteText", "Url",
#"FootnoteType", "Topic_clean", "Category_clean", "Data_Value_Type_clean", "CountyName_clean", "FootnoteText_clean", "Url_clean", "FootnoteType_clean", "Data_Value_Footnote_Symbol_clean", "Data_Value_Footnote_clean"
#],
#errors="ignore"
#)
#National_Retina_clean = National_Retina[
#National_Retina["LocationDesc"].isin(["Missouri", "National"])
#]
#National_Retina_clean = National_Retina_clean.drop(
#columns=[
#"Risk_Factor_Response", "Data_Value_Footnote", "Data_Value_Footnote_Symbol", "Topic", "Category", "Question", "Response", "Data_Value_Type", "Risk_Factor", "CountyName", "FootnoteText", "Url",
#"FootnoteType", "Topic_clean", "Category_clean", "Data_Value_Type_clean", "CountyName_clean", "FootnoteText_clean", "Url_clean", "FootnoteType_clean", "Data_Value_Footnote_Symbol_clean", "Data_Value_Footnote_clean"
#],
#errors="ignore"
#)
#National_AMD_clean = National_AMD[
#National_AMD["LocationDesc"].isin(["Missouri", "National"])
#]
#National_AMD_clean = National_AMD_clean.drop(
#columns=[
#"Risk_Factor_Response", "Data_Value_Footnote", "Data_Value_Footnote_Symbol", "Topic", "Category", "Question", "Response", "Data_Value_Type", "Risk_Factor", "CountyName", "FootnoteText", "Url",
#"FootnoteType", "Topic_clean", "Category_clean", "Data_Value_Type_clean", "CountyName_clean", "FootnoteText_clean", "Url_clean", "FootnoteType_clean", "Data_Value_Footnote_Symbol_clean", "Data_Value_Footnote_clean"
#],
#errors="ignore"
#)
#National_Glaucoma_clean = National_Glaucoma[
#National_Glaucoma["LocationDesc"].isin(["Missouri", "National"])
#]
#National_Glaucoma_clean = National_Glaucoma_clean.drop(
#columns=[
#"Risk_Factor_Response", "Data_Value_Footnote", "Data_Value_Footnote_Symbol", "Topic", "Category", "Question", "Response", "Data_Value_Type", "Risk_Factor", "CountyName", "FootnoteText", "Url",
#"FootnoteType", "Topic_clean", "Category_clean", "Data_Value_Type_clean", "CountyName_clean", "FootnoteText_clean", "Url_clean", "FootnoteType_clean", "Data_Value_Footnote_Symbol_clean", "Data_Value_Footnote_clean"
#],
#errors="ignore"
#)
#National_Cornea_clean = National_Cornea[
#National_Cornea["LocationDesc"].isin(["Missouri", "National"])
#]
#National_Cornea_clean = National_Cornea_clean.drop(
#columns=[
#"Risk_Factor_Response", "Data_Value_Footnote", "Data_Value_Footnote_Symbol", "Topic", "Category", "Question", "Response", "Data_Value_Type", "Risk_Factor", "CountyName", "FootnoteText", "Url",
#"FootnoteType", "Topic_clean", "Category_clean", "Data_Value_Type_clean", "CountyName_clean", "FootnoteText_clean", "Url_clean", "FootnoteType_clean", "Data_Value_Footnote_Symbol_clean", "Data_Value_Footnote_clean"
#],
#errors="ignore"
#)
# Out:
#      YearStart  YearEnd LocationAbbr LocationDesc       DataSource       Age  \
# 76        2022     2022           MO     Missouri  Medicare FFS MA  All Ages
# 81        2022     2022           US     National  Medicare FFS MA  All Ages
# 141       2022     2022           MO     Missouri  Medicare FFS MA  All Ages
# 151       2022     2022           US     National  Medicare FFS MA  All Ages
# 155       2022     2022           MO     Missouri  Medicare FFS MA  All Ages
# 179       2022     2022           US     National  Medicare FFS MA  All Ages
# 186       2022     2022           US     National  Medicare FFS MA  All Ages
# 192       2022     2022           MO     Missouri  Medicare FFS MA  All Ages
# 258       2022     2022           MO     Missouri  Medicare FFS MA  All Ages
# 285       2022     2022           MO     Missouri  Medicare FFS MA  All Ages
# 293       2022     2022           US     National  Medicare FFS MA  All Ages
# ...

# %% [markdown]
# ## Inconsistent Data
#
# Check for inconsistent data and address any that arises. As always, use code comments to illustrate your thought process.

# %% [markdown]
# Final Clean Data

# %% [markdown]
# ## Summarize Your Results
#
# Make note of your answers to the following questions.
#
# 1. Did you find all four types of dirty data in your dataset? I find Unecessary Data, Missing Data, and Irregular Data. However most of the Irregular and Missing Data I cleaned out when I got rid of the unecessary colums and rows.
# 2. Did the process of cleaning your data give you new insights into your dataset? The Insight I gained was that a lot of the data I had was irrelevant to my question besides certains rows and columns.
# 3. Is there anything you would like to make note of when it comes to manipulating the data and making visualizations? I would clean the data in excel which is much easier before importing the data into Vscode.
